# %%
from collections import defaultdict
from __future__ import print_function

import copy
import os
import itertools
import operator
import pickle
import random
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
% matplotlib inline

# %%
# Environment Parameters
GRID_HEIGHT = 4 
GRID_WIDTH = 12
TIME_PENALTY = -1
FALL_PENALTY = -10
START = (1,1)
GOAL = (GRID_WIDTH, 1)
ACTIONS = [
    (0, 1),  #UP
    (0, -1), #DOWN
    (1, 0),  #RIGHT
    (-1, 0)  #LEFT
]
ACTION_PLOT = {
    (0, 1) : u'\u2191',
    (0, -1) : u'\u2193',
    (1, 0) : u'\u2192',
    (-1, 0) : u'\u2190',
    None : '-'
}
STATE_LISTS = [range(1, GRID_WIDTH + 1), range(1, GRID_HEIGHT + 1)]
STATES = list(itertools.product(*STATE_LISTS))
NUM_EPISODES = 500
# Epsilon for epsilon greedy agent.
EPSILON = 0.1
ALPHA = 0.1
GAMMA = 1

# %%
def is_valid_state(state):
    x, y = state[0], state[1]
    return x in range(1, GRID_WIDTH + 1) and y in range(1, GRID_HEIGHT + 1)

def is_start_state(state):
    assert is_valid_state(state)
    return state == START

def is_goal_state(state):
    assert is_valid_state(state)
    return state == GOAL

def is_cliff_state(state):
    assert is_valid_state(state)
    x, y = state[0], state[1]
    return (y == 1) and (not is_start_state(state)) and (not is_goal_state(state))

def is_terminal_state(state):
    return is_goal_state(state) or is_cliff_state(state)

# NOTE : This can return invalid states if action is invalid.
def get_next_state(state, action):
    if is_terminal_state(state):
        return state
    return tuple(map(operator.add, state, action))

def get_valid_actions(state):
    # There are no actions in terminal states. We return all actions since reward for terminal states is 0
    # and get_next_state is designed to not make any transitions in terminal states.
    if is_terminal_state(state):
        return ACTIONS
    valid_actions = []
    for action in ACTIONS:
        if is_valid_state(get_next_state(state, action)):
            valid_actions.append(action)
    return valid_actions

def act(state, action):
    assert not is_terminal_state(state)
    next_state = get_next_state(state, action)
    if is_cliff_state(next_state):
        reward = FALL_PENALTY
    elif is_goal_state(next_state):
        reward = 0
    else:
        reward = TIME_PENALTY
    return next_state, reward

def init_q(Q):
    for state in STATES:
        valid_actions = get_valid_actions(state)
        for action in valid_actions:
            next_state = get_next_state(state, action)
            if is_valid_state(next_state):
                Q[state][action] = 0

# %%
def get_random_action(state):
    # For non-terminal states there is atleast one valid action.
    # For terminal states it doesn't matter what action we return since all have reward 0.    
    valid_actions = get_valid_actions(state)
    assert len(valid_actions) > 0
    return random.choice(valid_actions)

def get_greedy_action(Q, state):
    return max(Q[state], key=Q[state].get)

def get_epsilon_greedy_action(Q, state):
    # Choose an exploratory action with probability epsilon
    if random.random() < EPSILON:
#         print('Returning Random Choice')
        return get_random_action(state)
    # Return greedy action
    return get_greedy_action(Q, state)

def get_optimal_policy(Q, state):
    optimal_policy = {} 
    visited = {}
    while not is_terminal_state(state):
        optimal_action = get_greedy_action(Q, state)
        optimal_policy[state] = optimal_action
        visited[state] = True
        state = get_next_state(state, optimal_action)
        if state in visited:
            break
    return optimal_policy

def plot_policy(policy):
    for y in reversed(xrange(1, GRID_HEIGHT + 1)):
        print('')
        for x in xrange(1, GRID_WIDTH + 1):
            state = (x,y)
            if is_start_state(state):
                char = 'S'
            elif is_goal_state(state):
                char = 'G'
            elif is_cliff_state(state):
                char = 'C'
            else:
                action = policy[state] if state in policy else None
                char = (ACTION_PLOT[action])
            print('%s  ' %(char), end='')

def get_smoothed_list(list_to_smooth, window_size = 10):
    num_episodes = len(list_to_smooth)
    smoothed_list = []
    cur_sum = sum(list_to_smooth[:window_size])
    smoothed_list.append(cur_sum * 1.0 / window_size)
    for i in xrange(window_size, num_episodes):
        cur_sum -= list_to_smooth[i-window_size]
        cur_sum += list_to_smooth[i]
        smoothed_list.append(cur_sum * 1.0 / window_size)
    return smoothed_list

def plot_smoothed_list(list1, list2, xlabel, ylabel, legend_labels):
    plt.plot(get_smoothed_list(list1))
    plt.plot(get_smoothed_list(list2))
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend(legend_labels, loc='best')

# %%
def td_learning(num_episodes, td_type='SARSA'):
    Q = defaultdict(dict)
    init_q(Q)
    episode_rewards = []
    episode_steps = []
    for episode in xrange(num_episodes):
        print('Episode {0}'.format(episode))
        state = START
        action = get_epsilon_greedy_action(Q, state)
        episode_reward = 0
        steps = 0
        while not is_terminal_state(state):
            next_state, reward = act(state, action)
            episode_reward += reward
            steps += 1
            next_action = get_epsilon_greedy_action(Q, next_state)
            if td_type == 'SARSA':
                update_action = next_action
            elif td_type == 'QLEARNING':
                update_action = get_greedy_action(Q, next_state)
            else:
                raise Exception('Invalid TD Type %s' % (td_type))
            print('State:{0} Action:{1} Reward{2} NextState:{3} NextAction{4}'.format(state, action, reward,
                                                                                      next_state, next_action))
            Q[state][action] += ALPHA * (reward + GAMMA * Q[next_state][update_action] - Q[state][action])
            state, action = next_state, next_action
        episode_rewards.append(episode_reward)
        episode_steps.append(steps)
    optimal_policy = get_optimal_policy(Q, START)
    return episode_rewards, episode_steps, optimal_policy, Q

# %%
sarsa_rewards, sarsa_steps, sarsa_policy, _ = td_learning(NUM_EPISODES, 'SARSA')
# Out:
# Episode 0
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(1, 0)
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 1
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(0, -1)
# State:(2, 2) Action:(0, -1) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 2
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(0, -1)
# State:(5, 2) Action:(0, -1) Reward-10 NextState:(5, 1) NextAction(0, 1)
# Episode 3
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(0, 1)
# State:(6, 3) Action:(0, 1) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(0, 1)
# State:(7, 3) Action:(0, 1) Reward-1 NextState:(7, 4) NextAction(0, -1)
# State:(7, 4) Action:(0, -1) Reward-1 NextState:(7, 3) NextAction(0, -1)
# State:(7, 3) Action:(0, -1) Reward-1 NextState:(7, 2) NextAction(0, 1)
# State:(7, 2) Action:(0, 1) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(0, 1)
# State:(8, 3) Action:(0, 1) Reward-1 NextState:(8, 4) NextAction(0, -1)
# State:(8, 4) Action:(0, -1) Reward-1 NextState:(8, 3) NextAction(1, 0)
# State:(8, 3) Action:(1, 0) Reward-1 NextState:(9, 3) NextAction(1, 0)
# State:(9, 3) Action:(1, 0) Reward-1 NextState:(10, 3) NextAction(0, -1)
# State:(10, 3) Action:(0, -1) Reward-1 NextState:(10, 2) NextAction(0, 1)
# State:(10, 2) Action:(0, 1) Reward-1 NextState:(10, 3) NextAction(0, 1)
# State:(10, 3) Action:(0, 1) Reward-1 NextState:(10, 4) NextAction(0, -1)
# State:(10, 4) Action:(0, -1) Reward-1 NextState:(10, 3) NextAction(0, -1)
# State:(10, 3) Action:(0, -1) Reward-1 NextState:(10, 2) NextAction(0, -1)
# State:(10, 2) Action:(0, -1) Reward-10 NextState:(10, 1) NextAction(0, 1)
# Episode 4
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(1, 0)
# State:(8, 4) Action:(1, 0) Reward-1 NextState:(9, 4) NextAction(0, -1)
# State:(9, 4) Action:(0, -1) Reward-1 NextState:(9, 3) NextAction(0, 1)
# State:(9, 3) Action:(0, 1) Reward-1 NextState:(9, 4) NextAction(1, 0)
# State:(9, 4) Action:(1, 0) Reward-1 NextState:(10, 4) NextAction(1, 0)
# State:(10, 4) Action:(1, 0) Reward-1 NextState:(11, 4) NextAction(0, -1)
# State:(11, 4) Action:(0, -1) Reward-1 NextState:(11, 3) NextAction(0, 1)
# State:(11, 3) Action:(0, 1) Reward-1 NextState:(11, 4) NextAction(1, 0)
# State:(11, 4) Action:(1, 0) Reward-1 NextState:(12, 4) NextAction(0, -1)
# State:(12, 4) Action:(0, -1) Reward-1 NextState:(12, 3) NextAction(0, 1)
# State:(12, 3) Action:(0, 1) Reward-1 NextState:(12, 4) NextAction(-1, 0)
# State:(12, 4) Action:(-1, 0) Reward-1 NextState:(11, 4) NextAction(-1, 0)
# State:(11, 4) Action:(-1, 0) Reward-1 NextState:(10, 4) NextAction(-1, 0)
# State:(10, 4) Action:(-1, 0) Reward-1 NextState:(9, 4) NextAction(-1, 0)
# State:(9, 4) Action:(-1, 0) Reward-1 NextState:(8, 4) NextAction(-1, 0)
# State:(8, 4) Action:(-1, 0) Reward-1 NextState:(7, 4) NextAction(-1, 0)
# State:(7, 4) Action:(-1, 0) Reward-1 NextState:(6, 4) NextAction(-1, 0)
# State:(6, 4) Action:(-1, 0) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(0, -1)
# State:(3, 2) Action:(0, -1) Reward-10 NextState:(3, 1) NextAction(0, 1)
# Episode 5
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(0, -1)
# State:(4, 2) Action:(0, -1) Reward-10 NextState:(4, 1) NextAction(0, 1)
# Episode 6
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(-1, 0)
# State:(6, 3) Action:(-1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(0, -1)
# State:(6, 2) Action:(0, -1) Reward-10 NextState:(6, 1) NextAction(0, 1)
# Episode 7
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(0, 1)
# State:(6, 3) Action:(0, 1) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(0, -1)
# State:(7, 4) Action:(0, -1) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(0, -1)
# State:(8, 3) Action:(0, -1) Reward-1 NextState:(8, 2) NextAction(0, 1)
# State:(8, 2) Action:(0, 1) Reward-1 NextState:(8, 3) NextAction(-1, 0)
# State:(8, 3) Action:(-1, 0) Reward-1 NextState:(7, 3) NextAction(-1, 0)
# State:(7, 3) Action:(-1, 0) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(0, 1)
# State:(7, 2) Action:(0, 1) Reward-1 NextState:(7, 3) NextAction(0, 1)
# State:(7, 3) Action:(0, 1) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(0, -1)
# State:(8, 4) Action:(0, -1) Reward-1 NextState:(8, 3) NextAction(0, 1)
# State:(8, 3) Action:(0, 1) Reward-1 NextState:(8, 4) NextAction(1, 0)
# State:(8, 4) Action:(1, 0) Reward-1 NextState:(9, 4) NextAction(0, -1)
# State:(9, 4) Action:(0, -1) Reward-1 NextState:(9, 3) NextAction(0, -1)
# State:(9, 3) Action:(0, -1) Reward-1 NextState:(9, 2) NextAction(0, 1)
# State:(9, 2) Action:(0, 1) Reward-1 NextState:(9, 3) NextAction(-1, 0)
# State:(9, 3) Action:(-1, 0) Reward-1 NextState:(8, 3) NextAction(0, -1)
# State:(8, 3) Action:(0, -1) Reward-1 NextState:(8, 2) NextAction(0, -1)
# State:(8, 2) Action:(0, -1) Reward-10 NextState:(8, 1) NextAction(0, 1)
# Episode 8
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(-1, 0)
# State:(6, 2) Action:(-1, 0) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(0, -1)
# State:(7, 3) Action:(0, -1) Reward-1 NextState:(7, 2) NextAction(0, -1)
# State:(7, 2) Action:(0, -1) Reward-10 NextState:(7, 1) NextAction(0, 1)
# Episode 9
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 10
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(-1, 0)
# State:(7, 4) Action:(-1, 0) Reward-1 NextState:(6, 4) NextAction(-1, 0)
# State:(6, 4) Action:(-1, 0) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(-1, 0)
# State:(6, 3) Action:(-1, 0) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(1, 0)
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(1, 0)
# State:(8, 2) Action:(1, 0) Reward-1 NextState:(9, 2) NextAction(0, -1)
# State:(9, 2) Action:(0, -1) Reward-10 NextState:(9, 1) NextAction(0, 1)
# Episode 11
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(-1, 0)
# State:(6, 2) Action:(-1, 0) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(0, 1)
# State:(6, 3) Action:(0, 1) Reward-1 NextState:(6, 4) NextAction(-1, 0)
# State:(6, 4) Action:(-1, 0) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(-1, 0)
# State:(7, 3) Action:(-1, 0) Reward-1 NextState:(6, 3) NextAction(-1, 0)
# State:(6, 3) Action:(-1, 0) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(0, -1)
# State:(7, 4) Action:(0, -1) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(0, -1)
# State:(8, 3) Action:(0, -1) Reward-1 NextState:(8, 2) NextAction(-1, 0)
# State:(8, 2) Action:(-1, 0) Reward-1 NextState:(7, 2) NextAction(1, 0)
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(0, 1)
# State:(8, 2) Action:(0, 1) Reward-1 NextState:(8, 3) NextAction(1, 0)
# State:(8, 3) Action:(1, 0) Reward-1 NextState:(9, 3) NextAction(0, 1)
# State:(9, 3) Action:(0, 1) Reward-1 NextState:(9, 4) NextAction(1, 0)
# State:(9, 4) Action:(1, 0) Reward-1 NextState:(10, 4) NextAction(1, 0)
# State:(10, 4) Action:(1, 0) Reward-1 NextState:(11, 4) NextAction(0, -1)
# State:(11, 4) Action:(0, -1) Reward-1 NextState:(11, 3) NextAction(0, -1)
# State:(11, 3) Action:(0, -1) Reward-1 NextState:(11, 2) NextAction(0, 1)
# State:(11, 2) Action:(0, 1) Reward-1 NextState:(11, 3) NextAction(1, 0)
# State:(11, 3) Action:(1, 0) Reward-1 NextState:(12, 3) NextAction(0, -1)
# State:(12, 3) Action:(0, -1) Reward-1 NextState:(12, 2) NextAction(0, 1)
# State:(12, 2) Action:(0, 1) Reward-1 NextState:(12, 3) NextAction(-1, 0)
# State:(12, 3) Action:(-1, 0) Reward-1 NextState:(11, 3) NextAction(-1, 0)
# State:(11, 3) Action:(-1, 0) Reward-1 NextState:(10, 3) NextAction(1, 0)
# State:(10, 3) Action:(1, 0) Reward-1 NextState:(11, 3) NextAction(0, 1)
# State:(11, 3) Action:(0, 1) Reward-1 NextState:(11, 4) NextAction(1, 0)
# State:(11, 4) Action:(1, 0) Reward-1 NextState:(12, 4) NextAction(0, -1)
# State:(12, 4) Action:(0, -1) Reward-1 NextState:(12, 3) NextAction(0, 1)
# State:(12, 3) Action:(0, 1) Reward-1 NextState:(12, 4) NextAction(-1, 0)
# State:(12, 4) Action:(-1, 0) Reward-1 NextState:(11, 4) NextAction(-1, 0)
# State:(11, 4) Action:(-1, 0) Reward-1 NextState:(10, 4) NextAction(-1, 0)
# State:(10, 4) Action:(-1, 0) Reward-1 NextState:(9, 4) NextAction(-1, 0)
# State:(9, 4) Action:(-1, 0) Reward-1 NextState:(8, 4) NextAction(-1, 0)
# State:(8, 4) Action:(-1, 0) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(0, -1)
# State:(8, 4) Action:(0, -1) Reward-1 NextState:(8, 3) NextAction(-1, 0)
# State:(8, 3) Action:(-1, 0) Reward-1 NextState:(7, 3) NextAction(0, -1)
# State:(7, 3) Action:(0, -1) Reward-1 NextState:(7, 2) NextAction(-1, 0)
# State:(7, 2) Action:(-1, 0) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(-1, 0)
# State:(7, 2) Action:(-1, 0) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(-1, 0)
# State:(6, 2) Action:(-1, 0) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(0, -1)
# State:(4, 2) Action:(0, -1) Reward-10 NextState:(4, 1) NextAction(0, 1)
# Episode 12
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(0, 1)
# State:(7, 3) Action:(0, 1) Reward-1 NextState:(7, 4) NextAction(-1, 0)
# State:(7, 4) Action:(-1, 0) Reward-1 NextState:(6, 4) NextAction(-1, 0)
# State:(6, 4) Action:(-1, 0) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(0, 1)
# State:(6, 3) Action:(0, 1) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(-1, 0)
# State:(7, 4) Action:(-1, 0) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(-1, 0)
# State:(6, 3) Action:(-1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(0, 1)
# State:(7, 2) Action:(0, 1) Reward-1 NextState:(7, 3) NextAction(-1, 0)
# State:(7, 3) Action:(-1, 0) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(0, 1)
# State:(6, 3) Action:(0, 1) Reward-1 NextState:(6, 4) NextAction(-1, 0)
# State:(6, 4) Action:(-1, 0) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(0, -1)
# State:(7, 4) Action:(0, -1) Reward-1 NextState:(7, 3) NextAction(0, -1)
# State:(7, 3) Action:(0, -1) Reward-1 NextState:(7, 2) NextAction(1, 0)
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(1, 0)
# State:(8, 2) Action:(1, 0) Reward-1 NextState:(9, 2) NextAction(1, 0)
# State:(9, 2) Action:(1, 0) Reward-1 NextState:(10, 2) NextAction(1, 0)
# State:(10, 2) Action:(1, 0) Reward-1 NextState:(11, 2) NextAction(0, -1)
# State:(11, 2) Action:(0, -1) Reward-10 NextState:(11, 1) NextAction(0, 1)
# Episode 13
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(-1, 0)
# State:(6, 2) Action:(-1, 0) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(0, 1)
# State:(8, 3) Action:(0, 1) Reward-1 NextState:(8, 4) NextAction(1, 0)
# State:(8, 4) Action:(1, 0) Reward-1 NextState:(9, 4) NextAction(0, -1)
# State:(9, 4) Action:(0, -1) Reward-1 NextState:(9, 3) NextAction(0, -1)
# State:(9, 3) Action:(0, -1) Reward-1 NextState:(9, 2) NextAction(-1, 0)
# State:(9, 2) Action:(-1, 0) Reward-1 NextState:(8, 2) NextAction(-1, 0)
# State:(8, 2) Action:(-1, 0) Reward-1 NextState:(7, 2) NextAction(-1, 0)
# State:(7, 2) Action:(-1, 0) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(1, 0)
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(1, 0)
# State:(8, 2) Action:(1, 0) Reward-1 NextState:(9, 2) NextAction(0, 1)
# State:(9, 2) Action:(0, 1) Reward-1 NextState:(9, 3) NextAction(1, 0)
# State:(9, 3) Action:(1, 0) Reward-1 NextState:(10, 3) NextAction(-1, 0)
# State:(10, 3) Action:(-1, 0) Reward-1 NextState:(9, 3) NextAction(-1, 0)
# State:(9, 3) Action:(-1, 0) Reward-1 NextState:(8, 3) NextAction(1, 0)
# State:(8, 3) Action:(1, 0) Reward-1 NextState:(9, 3) NextAction(0, -1)
# State:(9, 3) Action:(0, -1) Reward-1 NextState:(9, 2) NextAction(1, 0)
# State:(9, 2) Action:(1, 0) Reward-1 NextState:(10, 2) NextAction(-1, 0)
# State:(10, 2) Action:(-1, 0) Reward-1 NextState:(9, 2) NextAction(-1, 0)
# State:(9, 2) Action:(-1, 0) Reward-1 NextState:(8, 2) NextAction(0, 1)
# State:(8, 2) Action:(0, 1) Reward-1 NextState:(8, 3) NextAction(-1, 0)
# State:(8, 3) Action:(-1, 0) Reward-1 NextState:(7, 3) NextAction(0, 1)
# State:(7, 3) Action:(0, 1) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(-1, 0)
# State:(8, 4) Action:(-1, 0) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(1, 0)
# State:(8, 4) Action:(1, 0) Reward-1 NextState:(9, 4) NextAction(1, 0)
# State:(9, 4) Action:(1, 0) Reward-1 NextState:(10, 4) NextAction(0, -1)
# State:(10, 4) Action:(0, -1) Reward-1 NextState:(10, 3) NextAction(-1, 0)
# State:(10, 3) Action:(-1, 0) Reward-1 NextState:(9, 3) NextAction(1, 0)
# State:(9, 3) Action:(1, 0) Reward-1 NextState:(10, 3) NextAction(0, 1)
# State:(10, 3) Action:(0, 1) Reward-1 NextState:(10, 4) NextAction(1, 0)
# State:(10, 4) Action:(1, 0) Reward-1 NextState:(11, 4) NextAction(0, -1)
# State:(11, 4) Action:(0, -1) Reward-1 NextState:(11, 3) NextAction(0, -1)
# State:(11, 3) Action:(0, -1) Reward-1 NextState:(11, 2) NextAction(1, 0)
# State:(11, 2) Action:(1, 0) Reward-1 NextState:(12, 2) NextAction(0, -1)
# State:(12, 2) Action:(0, -1) Reward0 NextState:(12, 1) NextAction(0, -1)
# Episode 14
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, -1)
# State:(2, 2) Action:(0, -1) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 15
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(1, 0)
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 16
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(-1, 0)
# State:(6, 3) Action:(-1, 0) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(-1, 0)
# State:(6, 2) Action:(-1, 0) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# ...
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(-1, 0)
# State:(6, 2) Action:(-1, 0) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(-1, 0)
# State:(7, 2) Action:(-1, 0) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(1, 0)
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(-1, 0)
# State:(8, 2) Action:(-1, 0) Reward-1 NextState:(7, 2) NextAction(0, 1)
# State:(7, 2) Action:(0, 1) Reward-1 NextState:(7, 3) NextAction(0, 1)
# State:(7, 3) Action:(0, 1) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(0, -1)
# State:(8, 4) Action:(0, -1) Reward-1 NextState:(8, 3) NextAction(1, 0)
# State:(8, 3) Action:(1, 0) Reward-1 NextState:(9, 3) NextAction(0, -1)
# State:(9, 3) Action:(0, -1) Reward-1 NextState:(9, 2) NextAction(1, 0)
# State:(9, 2) Action:(1, 0) Reward-1 NextState:(10, 2) NextAction(1, 0)
# State:(10, 2) Action:(1, 0) Reward-1 NextState:(11, 2) NextAction(1, 0)
# State:(11, 2) Action:(1, 0) Reward-1 NextState:(12, 2) NextAction(0, -1)
# State:(12, 2) Action:(0, -1) Reward0 NextState:(12, 1) NextAction(0, 1)
# Episode 397
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 398
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 399
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 400
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 401
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(0, 1)
# State:(6, 3) Action:(0, 1) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(-1, 0)
# State:(7, 4) Action:(-1, 0) Reward-1 NextState:(6, 4) NextAction(-1, 0)
# State:(6, 4) Action:(-1, 0) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(1, 0)
# State:(8, 3) Action:(1, 0) Reward-1 NextState:(9, 3) NextAction(0, 1)
# State:(9, 3) Action:(0, 1) Reward-1 NextState:(9, 4) NextAction(1, 0)
# State:(9, 4) Action:(1, 0) Reward-1 NextState:(10, 4) NextAction(0, -1)
# State:(10, 4) Action:(0, -1) Reward-1 NextState:(10, 3) NextAction(1, 0)
# State:(10, 3) Action:(1, 0) Reward-1 NextState:(11, 3) NextAction(0, -1)
# State:(11, 3) Action:(0, -1) Reward-1 NextState:(11, 2) NextAction(1, 0)
# State:(11, 2) Action:(1, 0) Reward-1 NextState:(12, 2) NextAction(0, -1)
# State:(12, 2) Action:(0, -1) Reward0 NextState:(12, 1) NextAction(0, 1)
# Episode 402
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 403
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, -1)
# Episode 404
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 405
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 406
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(1, 0)
# Episode 407
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(1, 0)
# State:(8, 4) Action:(1, 0) Reward-1 NextState:(9, 4) NextAction(0, -1)
# State:(9, 4) Action:(0, -1) Reward-1 NextState:(9, 3) NextAction(1, 0)
# State:(9, 3) Action:(1, 0) Reward-1 NextState:(10, 3) NextAction(-1, 0)
# State:(10, 3) Action:(-1, 0) Reward-1 NextState:(9, 3) NextAction(1, 0)
# State:(9, 3) Action:(1, 0) Reward-1 NextState:(10, 3) NextAction(1, 0)
# State:(10, 3) Action:(1, 0) Reward-1 NextState:(11, 3) NextAction(1, 0)
# State:(11, 3) Action:(1, 0) Reward-1 NextState:(12, 3) NextAction(0, -1)
# State:(12, 3) Action:(0, -1) Reward-1 NextState:(12, 2) NextAction(0, -1)
# State:(12, 2) Action:(0, -1) Reward0 NextState:(12, 1) NextAction(0, 1)
# Episode 408
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, -1)
# State:(2, 2) Action:(0, -1) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 409
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 410
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(1, 0)
# Episode 411
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 412
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 413
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 414
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 415
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 416
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 417
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 418
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 419
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 420
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 421
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 422
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 423
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, -1)
# Episode 424
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 425
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 426
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(1, 0)
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(1, 0)
# State:(8, 2) Action:(1, 0) Reward-1 NextState:(9, 2) NextAction(1, 0)
# State:(9, 2) Action:(1, 0) Reward-1 NextState:(10, 2) NextAction(1, 0)
# State:(10, 2) Action:(1, 0) Reward-1 NextState:(11, 2) NextAction(1, 0)
# State:(11, 2) Action:(1, 0) Reward-1 NextState:(12, 2) NextAction(0, -1)
# State:(12, 2) Action:(0, -1) Reward0 NextState:(12, 1) NextAction(0, 1)
# Episode 427
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 428
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 429
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 430
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 431
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 432
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 433
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 434
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 435
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, -1)
# Episode 436
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 437
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 438
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(-1, 0)
# Episode 439
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 440
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 441
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 442
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 443
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 444
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 445
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 446
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 447
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 448
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 449
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 450
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 451
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 452
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 453
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 454
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 455
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 456
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 457
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 458
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 459
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 460
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 461
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 462
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 463
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 464
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 465
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(-1, 0)
# Episode 466
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 467
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 468
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 469
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 470
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 471
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 472
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(-1, 0)
# Episode 473
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(1, 0)
# Episode 474
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 475
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 476
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 477
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 478
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 479
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 480
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 481
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 482
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 483
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 484
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, -1)
# Episode 485
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 486
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 487
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 488
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 489
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 490
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 491
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 492
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 493
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 494
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(1, 0)
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 495
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 496
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 497
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 498
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 499
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)

# %%
plot_policy(sarsa_policy)
# Out:
# -  -  -  -  -  -  -  -  -  -  -  -
# -  -  -  -  -  -  -  -  -  -  -  -
# -  -  -  -  -  -  -  -  -  -  -  -
# S  C  C  C  C  C  C  C  C  C  C  G

# %%
qlearning_rewards, qlearning_steps, qlearning_policy, _ = td_learning(NUM_EPISODES, 'QLEARNING')
# Out:
# Episode 0
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(1, 0)
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 1
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(0, -1)
# State:(2, 2) Action:(0, -1) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 2
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(0, 1)
# State:(6, 3) Action:(0, 1) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(0, -1)
# State:(7, 4) Action:(0, -1) Reward-1 NextState:(7, 3) NextAction(0, 1)
# State:(7, 3) Action:(0, 1) Reward-1 NextState:(7, 4) NextAction(-1, 0)
# State:(7, 4) Action:(-1, 0) Reward-1 NextState:(6, 4) NextAction(-1, 0)
# State:(6, 4) Action:(-1, 0) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(0, -1)
# State:(3, 2) Action:(0, -1) Reward-10 NextState:(3, 1) NextAction(0, 1)
# Episode 3
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(0, -1)
# State:(4, 2) Action:(0, -1) Reward-10 NextState:(4, 1) NextAction(0, 1)
# Episode 4
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(0, -1)
# State:(6, 2) Action:(0, -1) Reward-10 NextState:(6, 1) NextAction(0, 1)
# Episode 5
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(0, 1)
# State:(7, 2) Action:(0, 1) Reward-1 NextState:(7, 3) NextAction(0, -1)
# State:(7, 3) Action:(0, -1) Reward-1 NextState:(7, 2) NextAction(0, -1)
# State:(7, 2) Action:(0, -1) Reward-10 NextState:(7, 1) NextAction(0, 1)
# Episode 6
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(0, 1)
# State:(8, 3) Action:(0, 1) Reward-1 NextState:(8, 4) NextAction(0, -1)
# State:(8, 4) Action:(0, -1) Reward-1 NextState:(8, 3) NextAction(0, -1)
# State:(8, 3) Action:(0, -1) Reward-1 NextState:(8, 2) NextAction(0, 1)
# State:(8, 2) Action:(0, 1) Reward-1 NextState:(8, 3) NextAction(1, 0)
# State:(8, 3) Action:(1, 0) Reward-1 NextState:(9, 3) NextAction(0, 1)
# State:(9, 3) Action:(0, 1) Reward-1 NextState:(9, 4) NextAction(0, -1)
# State:(9, 4) Action:(0, -1) Reward-1 NextState:(9, 3) NextAction(0, -1)
# State:(9, 3) Action:(0, -1) Reward-1 NextState:(9, 2) NextAction(0, 1)
# State:(9, 2) Action:(0, 1) Reward-1 NextState:(9, 3) NextAction(1, 0)
# State:(9, 3) Action:(1, 0) Reward-1 NextState:(10, 3) NextAction(0, 1)
# State:(10, 3) Action:(0, 1) Reward-1 NextState:(10, 4) NextAction(0, -1)
# State:(10, 4) Action:(0, -1) Reward-1 NextState:(10, 3) NextAction(0, -1)
# State:(10, 3) Action:(0, -1) Reward-1 NextState:(10, 2) NextAction(0, 1)
# State:(10, 2) Action:(0, 1) Reward-1 NextState:(10, 3) NextAction(1, 0)
# State:(10, 3) Action:(1, 0) Reward-1 NextState:(11, 3) NextAction(0, 1)
# State:(11, 3) Action:(0, 1) Reward-1 NextState:(11, 4) NextAction(0, -1)
# State:(11, 4) Action:(0, -1) Reward-1 NextState:(11, 3) NextAction(0, -1)
# State:(11, 3) Action:(0, -1) Reward-1 NextState:(11, 2) NextAction(0, 1)
# State:(11, 2) Action:(0, 1) Reward-1 NextState:(11, 3) NextAction(1, 0)
# State:(11, 3) Action:(1, 0) Reward-1 NextState:(12, 3) NextAction(0, 1)
# State:(12, 3) Action:(0, 1) Reward-1 NextState:(12, 4) NextAction(0, -1)
# State:(12, 4) Action:(0, -1) Reward-1 NextState:(12, 3) NextAction(0, -1)
# State:(12, 3) Action:(0, -1) Reward-1 NextState:(12, 2) NextAction(0, -1)
# State:(12, 2) Action:(0, -1) Reward0 NextState:(12, 1) NextAction(0, 1)
# Episode 7
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(0, -1)
# State:(5, 2) Action:(0, -1) Reward-10 NextState:(5, 1) NextAction(-1, 0)
# Episode 8
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 9
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(-1, 0)
# State:(6, 3) Action:(-1, 0) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(-1, 0)
# State:(6, 2) Action:(-1, 0) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(0, -1)
# State:(4, 2) Action:(0, -1) Reward-10 NextState:(4, 1) NextAction(0, 1)
# Episode 10
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(0, 1)
# State:(6, 3) Action:(0, 1) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(1, 0)
# State:(8, 4) Action:(1, 0) Reward-1 NextState:(9, 4) NextAction(1, 0)
# State:(9, 4) Action:(1, 0) Reward-1 NextState:(10, 4) NextAction(1, 0)
# State:(10, 4) Action:(1, 0) Reward-1 NextState:(11, 4) NextAction(1, 0)
# State:(11, 4) Action:(1, 0) Reward-1 NextState:(12, 4) NextAction(-1, 0)
# State:(12, 4) Action:(-1, 0) Reward-1 NextState:(11, 4) NextAction(-1, 0)
# State:(11, 4) Action:(-1, 0) Reward-1 NextState:(10, 4) NextAction(-1, 0)
# State:(10, 4) Action:(-1, 0) Reward-1 NextState:(9, 4) NextAction(-1, 0)
# State:(9, 4) Action:(-1, 0) Reward-1 NextState:(8, 4) NextAction(-1, 0)
# State:(8, 4) Action:(-1, 0) Reward-1 NextState:(7, 4) NextAction(0, -1)
# State:(7, 4) Action:(0, -1) Reward-1 NextState:(7, 3) NextAction(-1, 0)
# State:(7, 3) Action:(-1, 0) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(0, 1)
# State:(7, 3) Action:(0, 1) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(0, -1)
# State:(8, 4) Action:(0, -1) Reward-1 NextState:(8, 3) NextAction(-1, 0)
# State:(8, 3) Action:(-1, 0) Reward-1 NextState:(7, 3) NextAction(0, -1)
# State:(7, 3) Action:(0, -1) Reward-1 NextState:(7, 2) NextAction(1, 0)
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(0, -1)
# State:(8, 2) Action:(0, -1) Reward-10 NextState:(8, 1) NextAction(0, 1)
# Episode 11
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 12
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(-1, 0)
# State:(6, 3) Action:(-1, 0) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(-1, 0)
# State:(6, 4) Action:(-1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(-1, 0)
# State:(7, 2) Action:(-1, 0) Reward-1 NextState:(6, 2) NextAction(-1, 0)
# State:(6, 2) Action:(-1, 0) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(0, 1)
# State:(7, 2) Action:(0, 1) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(0, 1)
# State:(8, 3) Action:(0, 1) Reward-1 NextState:(8, 4) NextAction(1, 0)
# State:(8, 4) Action:(1, 0) Reward-1 NextState:(9, 4) NextAction(0, -1)
# State:(9, 4) Action:(0, -1) Reward-1 NextState:(9, 3) NextAction(-1, 0)
# State:(9, 3) Action:(-1, 0) Reward-1 NextState:(8, 3) NextAction(0, -1)
# State:(8, 3) Action:(0, -1) Reward-1 NextState:(8, 2) NextAction(1, 0)
# State:(8, 2) Action:(1, 0) Reward-1 NextState:(9, 2) NextAction(1, 0)
# State:(9, 2) Action:(1, 0) Reward-1 NextState:(10, 2) NextAction(0, -1)
# State:(10, 2) Action:(0, -1) Reward-10 NextState:(10, 1) NextAction(0, 1)
# Episode 13
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(0, 1)
# State:(6, 3) Action:(0, 1) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(-1, 0)
# State:(7, 4) Action:(-1, 0) Reward-1 NextState:(6, 4) NextAction(-1, 0)
# State:(6, 4) Action:(-1, 0) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(0, -1)
# State:(7, 4) Action:(0, -1) Reward-1 NextState:(7, 3) NextAction(-1, 0)
# State:(7, 3) Action:(-1, 0) Reward-1 NextState:(6, 3) NextAction(0, 1)
# State:(6, 3) Action:(0, 1) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(0, -1)
# State:(7, 3) Action:(0, -1) Reward-1 NextState:(7, 2) NextAction(-1, 0)
# State:(7, 2) Action:(-1, 0) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(-1, 0)
# State:(6, 3) Action:(-1, 0) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(-1, 0)
# State:(6, 2) Action:(-1, 0) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(1, 0)
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(-1, 0)
# State:(8, 2) Action:(-1, 0) Reward-1 NextState:(7, 2) NextAction(1, 0)
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(-1, 0)
# State:(8, 2) Action:(-1, 0) Reward-1 NextState:(7, 2) NextAction(0, 1)
# State:(7, 2) Action:(0, 1) Reward-1 NextState:(7, 3) NextAction(0, 1)
# State:(7, 3) Action:(0, 1) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(-1, 0)
# State:(8, 4) Action:(-1, 0) Reward-1 NextState:(7, 4) NextAction(-1, 0)
# State:(7, 4) Action:(-1, 0) Reward-1 NextState:(6, 4) NextAction(-1, 0)
# State:(6, 4) Action:(-1, 0) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(0, 1)
# State:(8, 3) Action:(0, 1) Reward-1 NextState:(8, 4) NextAction(0, -1)
# State:(8, 4) Action:(0, -1) Reward-1 NextState:(8, 3) NextAction(1, 0)
# State:(8, 3) Action:(1, 0) Reward-1 NextState:(9, 3) NextAction(0, 1)
# State:(9, 3) Action:(0, 1) Reward-1 NextState:(9, 4) NextAction(-1, 0)
# State:(9, 4) Action:(-1, 0) Reward-1 NextState:(8, 4) NextAction(1, 0)
# State:(8, 4) Action:(1, 0) Reward-1 NextState:(9, 4) NextAction(1, 0)
# State:(9, 4) Action:(1, 0) Reward-1 NextState:(10, 4) NextAction(0, -1)
# State:(10, 4) Action:(0, -1) Reward-1 NextState:(10, 3) NextAction(-1, 0)
# State:(10, 3) Action:(-1, 0) Reward-1 NextState:(9, 3) NextAction(1, 0)
# State:(9, 3) Action:(1, 0) Reward-1 NextState:(10, 3) NextAction(0, 1)
# State:(10, 3) Action:(0, 1) Reward-1 NextState:(10, 4) NextAction(1, 0)
# State:(10, 4) Action:(1, 0) Reward-1 NextState:(11, 4) NextAction(0, -1)
# State:(11, 4) Action:(0, -1) Reward-1 NextState:(11, 3) NextAction(-1, 0)
# State:(11, 3) Action:(-1, 0) Reward-1 NextState:(10, 3) NextAction(0, -1)
# State:(10, 3) Action:(0, -1) Reward-1 NextState:(10, 2) NextAction(1, 0)
# State:(10, 2) Action:(1, 0) Reward-1 NextState:(11, 2) NextAction(0, -1)
# State:(11, 2) Action:(0, -1) Reward-10 NextState:(11, 1) NextAction(0, 1)
# Episode 14
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(-1, 0)
# State:(6, 3) Action:(-1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(0, -1)
# State:(2, 2) Action:(0, -1) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 15
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, -1)
# State:(1, 3) Action:(0, -1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(-1, 0)
# State:(5, 4) Action:(-1, 0) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(-1, 0)
# State:(6, 2) Action:(-1, 0) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(-1, 0)
# State:(7, 3) Action:(-1, 0) Reward-1 NextState:(6, 3) NextAction(0, 1)
# State:(6, 3) Action:(0, 1) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(0, -1)
# State:(7, 4) Action:(0, -1) Reward-1 NextState:(7, 3) NextAction(0, -1)
# State:(7, 3) Action:(0, -1) Reward-1 NextState:(7, 2) NextAction(-1, 0)
# State:(7, 2) Action:(-1, 0) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(1, 0)
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(0, 1)
# State:(8, 2) Action:(0, 1) Reward-1 NextState:(8, 3) NextAction(-1, 0)
# State:(8, 3) Action:(-1, 0) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(0, 1)
# State:(8, 3) Action:(0, 1) Reward-1 NextState:(8, 4) NextAction(-1, 0)
# State:(8, 4) Action:(-1, 0) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(0, -1)
# State:(8, 4) Action:(0, -1) Reward-1 NextState:(8, 3) NextAction(0, -1)
# State:(8, 3) Action:(0, -1) Reward-1 NextState:(8, 2) NextAction(1, 0)
# State:(8, 2) Action:(1, 0) Reward-1 NextState:(9, 2) NextAction(0, -1)
# State:(9, 2) Action:(0, -1) Reward-10 NextState:(9, 1) NextAction(0, 1)
# Episode 16
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, -1)
# State:(1, 2) Action:(0, -1) Reward-1 NextState:(1, 1) NextAction(0, 1)
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(-1, 0)
# State:(3, 3) Action:(-1, 0) Reward-1 NextState:(2, 3) NextAction(-1, 0)
# State:(2, 3) Action:(-1, 0) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, -1)
# State:(2, 3) Action:(0, -1) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(-1, 0)
# State:(6, 4) Action:(-1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(-1, 0)
# State:(5, 3) Action:(-1, 0) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(-1, 0)
# State:(4, 4) Action:(-1, 0) Reward-1 NextState:(3, 4) NextAction(0, -1)
# State:(3, 4) Action:(0, -1) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(-1, 0)
# State:(6, 3) Action:(-1, 0) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(-1, 0)
# State:(7, 4) Action:(-1, 0) Reward-1 NextState:(6, 4) NextAction(0, -1)
# State:(6, 4) Action:(0, -1) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(-1, 0)
# State:(6, 2) Action:(-1, 0) Reward-1 NextState:(5, 2) NextAction(-1, 0)
# State:(5, 2) Action:(-1, 0) Reward-1 NextState:(4, 2) NextAction(-1, 0)
# State:(4, 2) Action:(-1, 0) Reward-1 NextState:(3, 2) NextAction(-1, 0)
# State:(3, 2) Action:(-1, 0) Reward-1 NextState:(2, 2) NextAction(-1, 0)
# State:(2, 2) Action:(-1, 0) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(0, -1)
# State:(1, 4) Action:(0, -1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(0, 1)
# State:(7, 3) Action:(0, 1) Reward-1 NextState:(7, 4) NextAction(0, -1)
# State:(7, 4) Action:(0, -1) Reward-1 NextState:(7, 3) NextAction(-1, 0)
# ...
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(1, 0)
# State:(8, 2) Action:(1, 0) Reward-1 NextState:(9, 2) NextAction(1, 0)
# State:(9, 2) Action:(1, 0) Reward-1 NextState:(10, 2) NextAction(1, 0)
# State:(10, 2) Action:(1, 0) Reward-1 NextState:(11, 2) NextAction(1, 0)
# State:(11, 2) Action:(1, 0) Reward-1 NextState:(12, 2) NextAction(0, -1)
# State:(12, 2) Action:(0, -1) Reward0 NextState:(12, 1) NextAction(0, -1)
# Episode 393
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 394
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 395
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 396
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 397
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(1, 0)
# Episode 398
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 399
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, -1)
# Episode 400
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 401
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 402
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 403
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 404
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 405
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 406
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 407
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 408
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(-1, 0)
# Episode 409
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 410
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 411
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 412
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 413
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 414
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 415
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(0, -1)
# State:(4, 2) Action:(0, -1) Reward-10 NextState:(4, 1) NextAction(0, 1)
# Episode 416
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 417
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 418
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 419
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 420
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 421
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 422
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 423
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 424
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 425
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 426
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 427
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 428
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 429
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 430
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 431
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 432
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 433
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 434
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 435
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 436
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(0, 1)
# State:(1, 3) Action:(0, 1) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(-1, 0)
# State:(3, 4) Action:(-1, 0) Reward-1 NextState:(2, 4) NextAction(0, -1)
# State:(2, 4) Action:(0, -1) Reward-1 NextState:(2, 3) NextAction(0, 1)
# State:(2, 3) Action:(0, 1) Reward-1 NextState:(2, 4) NextAction(-1, 0)
# State:(2, 4) Action:(-1, 0) Reward-1 NextState:(1, 4) NextAction(1, 0)
# State:(1, 4) Action:(1, 0) Reward-1 NextState:(2, 4) NextAction(1, 0)
# State:(2, 4) Action:(1, 0) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(0, -1)
# State:(4, 4) Action:(0, -1) Reward-1 NextState:(4, 3) NextAction(0, -1)
# State:(4, 3) Action:(0, -1) Reward-1 NextState:(4, 2) NextAction(1, 0)
# State:(4, 2) Action:(1, 0) Reward-1 NextState:(5, 2) NextAction(1, 0)
# State:(5, 2) Action:(1, 0) Reward-1 NextState:(6, 2) NextAction(0, 1)
# State:(6, 2) Action:(0, 1) Reward-1 NextState:(6, 3) NextAction(0, -1)
# State:(6, 3) Action:(0, -1) Reward-1 NextState:(6, 2) NextAction(1, 0)
# State:(6, 2) Action:(1, 0) Reward-1 NextState:(7, 2) NextAction(0, 1)
# State:(7, 2) Action:(0, 1) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(1, 0)
# State:(8, 3) Action:(1, 0) Reward-1 NextState:(9, 3) NextAction(1, 0)
# State:(9, 3) Action:(1, 0) Reward-1 NextState:(10, 3) NextAction(0, -1)
# State:(10, 3) Action:(0, -1) Reward-1 NextState:(10, 2) NextAction(1, 0)
# State:(10, 2) Action:(1, 0) Reward-1 NextState:(11, 2) NextAction(1, 0)
# State:(11, 2) Action:(1, 0) Reward-1 NextState:(12, 2) NextAction(0, -1)
# State:(12, 2) Action:(0, -1) Reward0 NextState:(12, 1) NextAction(0, 1)
# Episode 437
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, -1)
# State:(2, 2) Action:(0, -1) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 438
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 439
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 440
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 441
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 442
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 443
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 444
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 445
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 446
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 447
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 448
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 449
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 450
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 451
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 452
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, -1)
# Episode 453
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 454
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 455
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 456
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 457
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 458
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 459
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 460
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, -1)
# Episode 461
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 462
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 463
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 464
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(0, 1)
# State:(1, 2) Action:(0, 1) Reward-1 NextState:(1, 3) NextAction(1, 0)
# State:(1, 3) Action:(1, 0) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(0, -1)
# State:(3, 3) Action:(0, -1) Reward-1 NextState:(3, 2) NextAction(1, 0)
# State:(3, 2) Action:(1, 0) Reward-1 NextState:(4, 2) NextAction(0, 1)
# State:(4, 2) Action:(0, 1) Reward-1 NextState:(4, 3) NextAction(0, 1)
# State:(4, 3) Action:(0, 1) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(0, -1)
# State:(5, 4) Action:(0, -1) Reward-1 NextState:(5, 3) NextAction(1, 0)
# State:(5, 3) Action:(1, 0) Reward-1 NextState:(6, 3) NextAction(1, 0)
# State:(6, 3) Action:(1, 0) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(0, -1)
# State:(8, 3) Action:(0, -1) Reward-1 NextState:(8, 2) NextAction(-1, 0)
# State:(8, 2) Action:(-1, 0) Reward-1 NextState:(7, 2) NextAction(1, 0)
# State:(7, 2) Action:(1, 0) Reward-1 NextState:(8, 2) NextAction(0, 1)
# State:(8, 2) Action:(0, 1) Reward-1 NextState:(8, 3) NextAction(1, 0)
# State:(8, 3) Action:(1, 0) Reward-1 NextState:(9, 3) NextAction(1, 0)
# State:(9, 3) Action:(1, 0) Reward-1 NextState:(10, 3) NextAction(-1, 0)
# State:(10, 3) Action:(-1, 0) Reward-1 NextState:(9, 3) NextAction(1, 0)
# State:(9, 3) Action:(1, 0) Reward-1 NextState:(10, 3) NextAction(1, 0)
# State:(10, 3) Action:(1, 0) Reward-1 NextState:(11, 3) NextAction(1, 0)
# State:(11, 3) Action:(1, 0) Reward-1 NextState:(12, 3) NextAction(0, -1)
# State:(12, 3) Action:(0, -1) Reward-1 NextState:(12, 2) NextAction(0, -1)
# State:(12, 2) Action:(0, -1) Reward0 NextState:(12, 1) NextAction(0, 1)
# Episode 465
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(-1, 0)
# Episode 466
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 467
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 468
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(1, 0)
# Episode 469
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 470
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(-1, 0)
# Episode 471
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 472
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 473
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(0, 1)
# State:(2, 2) Action:(0, 1) Reward-1 NextState:(2, 3) NextAction(1, 0)
# State:(2, 3) Action:(1, 0) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(-1, 0)
# State:(4, 3) Action:(-1, 0) Reward-1 NextState:(3, 3) NextAction(1, 0)
# State:(3, 3) Action:(1, 0) Reward-1 NextState:(4, 3) NextAction(1, 0)
# State:(4, 3) Action:(1, 0) Reward-1 NextState:(5, 3) NextAction(0, -1)
# State:(5, 3) Action:(0, -1) Reward-1 NextState:(5, 2) NextAction(0, 1)
# State:(5, 2) Action:(0, 1) Reward-1 NextState:(5, 3) NextAction(0, 1)
# State:(5, 3) Action:(0, 1) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(0, -1)
# State:(7, 4) Action:(0, -1) Reward-1 NextState:(7, 3) NextAction(0, 1)
# State:(7, 3) Action:(0, 1) Reward-1 NextState:(7, 4) NextAction(0, -1)
# State:(7, 4) Action:(0, -1) Reward-1 NextState:(7, 3) NextAction(1, 0)
# State:(7, 3) Action:(1, 0) Reward-1 NextState:(8, 3) NextAction(1, 0)
# State:(8, 3) Action:(1, 0) Reward-1 NextState:(9, 3) NextAction(0, -1)
# State:(9, 3) Action:(0, -1) Reward-1 NextState:(9, 2) NextAction(1, 0)
# State:(9, 2) Action:(1, 0) Reward-1 NextState:(10, 2) NextAction(1, 0)
# State:(10, 2) Action:(1, 0) Reward-1 NextState:(11, 2) NextAction(1, 0)
# State:(11, 2) Action:(1, 0) Reward-1 NextState:(12, 2) NextAction(0, -1)
# State:(12, 2) Action:(0, -1) Reward0 NextState:(12, 1) NextAction(0, 1)
# Episode 474
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 475
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 476
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 477
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 478
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 479
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 480
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(-1, 0)
# Episode 481
# State:(1, 1) Action:(0, 1) Reward-1 NextState:(1, 2) NextAction(1, 0)
# State:(1, 2) Action:(1, 0) Reward-1 NextState:(2, 2) NextAction(1, 0)
# State:(2, 2) Action:(1, 0) Reward-1 NextState:(3, 2) NextAction(0, 1)
# State:(3, 2) Action:(0, 1) Reward-1 NextState:(3, 3) NextAction(0, 1)
# State:(3, 3) Action:(0, 1) Reward-1 NextState:(3, 4) NextAction(1, 0)
# State:(3, 4) Action:(1, 0) Reward-1 NextState:(4, 4) NextAction(1, 0)
# State:(4, 4) Action:(1, 0) Reward-1 NextState:(5, 4) NextAction(1, 0)
# State:(5, 4) Action:(1, 0) Reward-1 NextState:(6, 4) NextAction(1, 0)
# State:(6, 4) Action:(1, 0) Reward-1 NextState:(7, 4) NextAction(1, 0)
# State:(7, 4) Action:(1, 0) Reward-1 NextState:(8, 4) NextAction(1, 0)
# State:(8, 4) Action:(1, 0) Reward-1 NextState:(9, 4) NextAction(1, 0)
# State:(9, 4) Action:(1, 0) Reward-1 NextState:(10, 4) NextAction(0, -1)
# State:(10, 4) Action:(0, -1) Reward-1 NextState:(10, 3) NextAction(1, 0)
# State:(10, 3) Action:(1, 0) Reward-1 NextState:(11, 3) NextAction(0, -1)
# State:(11, 3) Action:(0, -1) Reward-1 NextState:(11, 2) NextAction(1, 0)
# State:(11, 2) Action:(1, 0) Reward-1 NextState:(12, 2) NextAction(0, -1)
# State:(12, 2) Action:(0, -1) Reward0 NextState:(12, 1) NextAction(0, 1)
# Episode 482
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 483
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 484
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 485
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 486
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 487
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 488
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 489
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 490
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, -1)
# Episode 491
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 492
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 493
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 494
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, -1)
# Episode 495
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 496
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 497
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, -1)
# Episode 498
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)
# Episode 499
# State:(1, 1) Action:(1, 0) Reward-10 NextState:(2, 1) NextAction(0, 1)

# %%
plot_policy(qlearning_policy)
# Out:
# -  -  -  -  -  -  -  -  -  -  -  -
# -  -  -  -  -  -  -  -  -  -  -  -
# -  -  -  -  -  -  -  -  -  -  -  -
# S  C  C  C  C  C  C  C  C  C  C  G

# %%
plot_smoothed_list(sarsa_rewards, qlearning_rewards, 'Episode', 'Rewards', ['SARSA', 'QLearning'])

# %%
plot_smoothed_list(sarsa_steps, qlearning_steps, 'Episode', 'Steps', ['SARSA', 'QLearning'])
